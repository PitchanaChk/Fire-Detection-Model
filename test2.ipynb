# %%
import cv2
import pickle
import os
import time
import requests
import threading
from ultralytics import YOLO
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from threading import Thread
# Out:
# WARNING ⚠️ torchvision==0.20 is incompatible with torch==2.6.
# Run 'pip install torchvision==0.21' to fix torchvision or 'pip install -U torch torchvision' to update both.
# For a full compatibility table see https://github.com/pytorch/vision#installation

# %%
# ตั้งค่า LINE Notify
LINE_NOTIFY_TOKEN = "wDWc4yjjTH90dosYSXKva3tfhzW5Qz38NHgGHgt8HfL"
LINE_NOTIFY_URL = "https://notify-api.line.me/api/notify"

# %%
# Function to send LINE Notify message with image
def send_line_notify(message, image_path=None):
    headers = {"Authorization": f"Bearer {LINE_NOTIFY_TOKEN}"}
    data = {"message": message}

    if image_path:
        files = {"imageFile": open(image_path, "rb")}
        requests.post(LINE_NOTIFY_URL, headers=headers, data=data, files=files)
        files["imageFile"].close()
    else:
        requests.post(LINE_NOTIFY_URL, headers=headers, data=data)

# โหลดโมเดล YOLO
model = YOLO(r"runs/detect/train/weights/best.pt")

# โหลดวิดีโอ
video_path = "test_video/fire_test2.mp4"
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Failed to load video!")
    exit()

# โหลด Ground Truth ที่เคยบันทึกไว้
if os.path.exists("ground_truth\ground_truth2.pkl"):
    with open("ground_truth\ground_truth2.pkl", "rb") as f:
        ground_truth = pickle.load(f)
else:
    print("❌ ไม่พบไฟล์ Ground Truth! กรุณารัน 'collect_ground_truth.py' ก่อน")
    exit()

predictions = []  # เก็บค่าที่โมเดลคาดการณ์
frame_index = 0   # ใช้ในการอ้างอิง Ground Truth

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # วิดีโอจบ

    results = model(frame)
    fire_in_frame = False  # เริ่มต้นไม่มีไฟ

    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    for result in results:
        for box in result.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            conf = box.conf[0].item()
            label = result.names[int(box.cls[0])]

            if "fire" in label.lower() and conf > 0.50:
                fire_in_frame = True  # มีไฟในเฟรมนี้
                center_x, center_y = (x1 + x2) // 2, (y1 + y2) // 2
                box_size = (x2 - x1) * (y2 - y1)

                # 🔥 ระบุตำแหน่งไฟ
                horizontal_pos = "Left" if center_x < frame_width * 0.33 else "Right" if center_x > frame_width * 0.66 else "Center"
                vertical_pos = "Top" if center_y < frame_height * 0.33 else "Bottom" if center_y > frame_height * 0.66 else "Middle"
                depth_pos = "Near" if box_size > (frame_width * frame_height * 0.05) else "Far" if box_size < (frame_width * frame_height * 0.02) else "Mid-range"

                fire_location = f"{horizontal_pos}, {vertical_pos}, {depth_pos}"
                print(f"🚨 Fire detected at: {fire_location}")

                # วาดกล่องรอบไฟ
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
                cv2.putText(frame, fire_location, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

                # Save the frame with fire detection
                img_filename = "fire_detected_frame.jpg"
                cv2.imwrite(img_filename, frame)

                # Send LINE notification with image
                alert_message = f"🔥 Fire detected at: {fire_location}"
                Thread(target=send_line_notify, args=(alert_message, img_filename)).start()

    predictions.append(1 if fire_in_frame else 0)

    # แสดงผลวิดีโอ
    frame_resized = cv2.resize(frame, (1280, 720))
    cv2.imshow("🔥 Fire Detection System", frame_resized)

    # กด 'q' เพื่อออก
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

    frame_index += 1

cap.release()
cv2.destroyAllWindows()

# คำนวณค่าความแม่นยำ (Precision, Recall, F1-score, Accuracy)
if len(ground_truth) <= len(predictions):  # ตรวจสอบว่า ground_truth น้อยกว่าหรือเท่ากับ predictions
    min_length = min(len(ground_truth), len(predictions))  # เลือกขนาดที่น้อยกว่า

    # ตัด ground_truth และ predictions ให้มีขนาดเท่ากัน
    ground_truth = ground_truth[:min_length]
    predictions = predictions[:min_length]

    # คำนวณค่าความแม่นยำ
    recall = recall_score(ground_truth, predictions)
    f1 = f1_score(ground_truth, predictions)
    accuracy = accuracy_score(ground_truth, predictions)
    precision = precision_score(ground_truth, predictions)

    print(f"\n📊 **Accuracy Metrics**")
    print(f"✅ Precision: {precision:.4f}")
    print(f"✅ Recall: {recall:.4f}")
    print(f"✅ F1 Score: {f1:.4f}")
    print(f"✅ Accuracy: {accuracy:.4f}")

else:
    print("⚠️ จำนวนเฟรมของ Ground Truth น้อยกว่าผลลัพธ์ที่ได้ กรุณาเก็บ Ground Truth ใหม่!")
# Out:
# 0: 384x640 (no detections), 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 12.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.4ms
# Speed: 1.6ms preprocess, 7.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.7ms preprocess, 6.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 2.0ms preprocess, 6.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.8ms
# Speed: 1.4ms preprocess, 6.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 1.7ms preprocess, 6.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.8ms preprocess, 6.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.4ms
# Speed: 1.4ms preprocess, 8.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 22.1ms
# Speed: 3.3ms preprocess, 22.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.9ms
# Speed: 2.0ms preprocess, 6.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.5ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.3ms
# Speed: 5.3ms preprocess, 11.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.1ms
# Speed: 1.5ms preprocess, 6.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.4ms
# Speed: 1.4ms preprocess, 6.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.9ms
# Speed: 1.6ms preprocess, 5.9ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.2ms
# Speed: 1.6ms preprocess, 10.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.7ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.8ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.4ms
# Speed: 1.8ms preprocess, 6.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.6ms preprocess, 6.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.1ms
# Speed: 1.5ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.8ms preprocess, 5.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.0ms
# Speed: 1.4ms preprocess, 7.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.8ms preprocess, 5.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 1.7ms preprocess, 11.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.3ms
# Speed: 1.4ms preprocess, 6.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.9ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.3ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.1ms
# Speed: 1.5ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.2ms
# Speed: 2.0ms preprocess, 9.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.2ms
# Speed: 1.5ms preprocess, 8.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.3ms
# Speed: 1.6ms preprocess, 7.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.3ms
# Speed: 1.4ms preprocess, 9.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 2.2ms preprocess, 5.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.0ms
# Speed: 1.4ms preprocess, 6.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 10.5ms
# Speed: 1.7ms preprocess, 10.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.3ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.2ms preprocess, 5.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.4ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.3ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.6ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.0ms
# Speed: 1.4ms preprocess, 5.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.3ms
# Speed: 1.4ms preprocess, 9.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 8.0ms
# Speed: 2.3ms preprocess, 8.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 7.4ms
# Speed: 1.4ms preprocess, 7.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.6ms
# Speed: 1.4ms preprocess, 6.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.4ms
# Speed: 1.3ms preprocess, 5.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.1ms
# Speed: 1.3ms preprocess, 5.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 6.8ms
# Speed: 1.7ms preprocess, 6.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.4ms preprocess, 5.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.3ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.9ms
# Speed: 1.5ms preprocess, 5.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.7ms
# Speed: 1.3ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 5.5ms
# Speed: 1.3ms preprocess, 5.5ms inference, 58.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 5.5ms
# Speed: 2.0ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 10.1ms
# Speed: 1.5ms preprocess, 10.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fires, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.9ms
# Speed: 1.3ms preprocess, 5.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.3ms
# Speed: 1.3ms preprocess, 5.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 6.5ms
# Speed: 1.5ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 7.5ms
# Speed: 2.2ms preprocess, 7.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.2ms
# Speed: 1.6ms preprocess, 5.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.7ms
# Speed: 1.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.1ms
# Speed: 1.4ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.3ms
# Speed: 1.5ms preprocess, 5.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 6.0ms
# Speed: 2.1ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 10.8ms
# Speed: 1.6ms preprocess, 10.8ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 6.2ms
# Speed: 1.4ms preprocess, 6.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.8ms
# Speed: 1.4ms preprocess, 5.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.6ms
# Speed: 1.6ms preprocess, 5.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 7.2ms
# Speed: 2.5ms preprocess, 7.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.6ms
# Speed: 1.4ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.2ms
# Speed: 1.4ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.2ms
# Speed: 2.0ms preprocess, 8.2ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.3ms
# Speed: 2.4ms preprocess, 10.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 7.8ms
# Speed: 1.9ms preprocess, 7.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.0ms
# Speed: 1.8ms preprocess, 11.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 9.0ms
# Speed: 2.3ms preprocess, 9.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 11.4ms
# Speed: 2.4ms preprocess, 11.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 5.3ms
# Speed: 1.4ms preprocess, 5.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.4ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.7ms
# Speed: 1.5ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 4.8ms
# Speed: 1.4ms preprocess, 4.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.0ms
# Speed: 2.2ms preprocess, 5.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.7ms preprocess, 5.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.8ms
# Speed: 1.6ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.8ms
# Speed: 2.0ms preprocess, 5.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 2 fires, 6.5ms
# Speed: 1.6ms preprocess, 6.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.3ms
# Speed: 1.7ms preprocess, 5.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.7ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.7ms
# Speed: 1.6ms preprocess, 5.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.0ms
# Speed: 1.5ms preprocess, 5.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.5ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.8ms preprocess, 5.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.6ms preprocess, 5.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.6ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.3ms
# Speed: 1.8ms preprocess, 5.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 6.3ms
# Speed: 1.6ms preprocess, 6.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 6.2ms
# Speed: 1.7ms preprocess, 6.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.3ms
# Speed: 1.6ms preprocess, 5.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.7ms
# Speed: 1.4ms preprocess, 5.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.1ms
# Speed: 1.6ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 4.9ms
# Speed: 1.4ms preprocess, 4.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.3ms
# Speed: 1.9ms preprocess, 5.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 4.7ms
# Speed: 1.7ms preprocess, 4.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.1ms
# Speed: 3.4ms preprocess, 9.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.4ms
# Speed: 1.7ms preprocess, 5.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.2ms
# Speed: 1.8ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.8ms
# Speed: 1.5ms preprocess, 5.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.0ms
# Speed: 1.7ms preprocess, 5.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.0ms
# Speed: 1.9ms preprocess, 5.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 6.4ms
# Speed: 1.6ms preprocess, 6.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.2ms
# Speed: 1.5ms preprocess, 5.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.1ms
# Speed: 1.5ms preprocess, 5.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 6.3ms
# Speed: 1.5ms preprocess, 6.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 6.0ms
# Speed: 1.5ms preprocess, 6.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.5ms
# Speed: 1.5ms preprocess, 5.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 7.2ms
# Speed: 1.6ms preprocess, 7.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.6ms
# Speed: 1.5ms preprocess, 5.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 7.0ms
# Speed: 1.6ms preprocess, 7.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 5.0ms
# Speed: 2.0ms preprocess, 5.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 7.4ms
# Speed: 1.7ms preprocess, 7.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.7ms
# Speed: 2.2ms preprocess, 8.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.9ms
# Speed: 2.2ms preprocess, 9.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 11.0ms
# Speed: 2.1ms preprocess, 11.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.5ms
# Speed: 1.9ms preprocess, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 7.1ms
# Speed: 2.5ms preprocess, 7.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.8ms
# Speed: 2.0ms preprocess, 9.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.4ms
# Speed: 2.0ms preprocess, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 7.8ms
# Speed: 2.1ms preprocess, 7.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.9ms
# Speed: 1.9ms preprocess, 8.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.2ms
# Speed: 2.1ms preprocess, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.6ms
# Speed: 2.4ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 11.1ms
# Speed: 1.8ms preprocess, 11.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.5ms
# Speed: 1.9ms preprocess, 8.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.7ms
# Speed: 1.9ms preprocess, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.7ms
# Speed: 2.5ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 12.1ms
# Speed: 2.1ms preprocess, 12.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.9ms
# Speed: 1.9ms preprocess, 9.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.7ms
# Speed: 2.9ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.4ms
# Speed: 5.2ms preprocess, 8.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 12.4ms
# Speed: 1.8ms preprocess, 12.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.0ms
# Speed: 2.5ms preprocess, 9.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.5ms
# Speed: 2.2ms preprocess, 10.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.5ms
# Speed: 2.1ms preprocess, 10.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.1ms
# Speed: 1.9ms preprocess, 10.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.1ms
# Speed: 4.7ms preprocess, 8.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.5ms
# Speed: 2.0ms preprocess, 10.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.1ms
# Speed: 2.3ms preprocess, 8.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.3ms
# Speed: 1.9ms preprocess, 8.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.4ms
# Speed: 2.3ms preprocess, 8.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.6ms
# Speed: 2.2ms preprocess, 9.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.8ms
# Speed: 2.0ms preprocess, 8.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.4ms
# Speed: 2.2ms preprocess, 9.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 11.0ms
# Speed: 2.2ms preprocess, 11.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.7ms
# Speed: 1.8ms preprocess, 8.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.5ms
# Speed: 2.2ms preprocess, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.7ms
# Speed: 2.0ms preprocess, 8.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.1ms
# Speed: 2.0ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.9ms
# Speed: 2.0ms preprocess, 10.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 11.3ms
# Speed: 1.9ms preprocess, 11.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.3ms
# Speed: 2.1ms preprocess, 8.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.3ms
# Speed: 2.4ms preprocess, 8.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.4ms
# Speed: 2.3ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.1ms
# Speed: 2.2ms preprocess, 9.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.6ms
# Speed: 2.6ms preprocess, 9.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.8ms
# Speed: 1.8ms preprocess, 8.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.2ms
# Speed: 2.0ms preprocess, 10.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.5ms
# Speed: 2.0ms preprocess, 8.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 11.3ms
# Speed: 2.4ms preprocess, 11.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 11.4ms
# Speed: 3.1ms preprocess, 11.4ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 14.1ms
# Speed: 3.2ms preprocess, 14.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 14.9ms
# Speed: 2.1ms preprocess, 14.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.4ms
# Speed: 2.2ms preprocess, 10.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.7ms
# Speed: 2.1ms preprocess, 10.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.9ms
# Speed: 2.4ms preprocess, 9.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 8.2ms
# Speed: 2.5ms preprocess, 8.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.3ms
# Speed: 3.0ms preprocess, 10.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.4ms
# Speed: 2.0ms preprocess, 10.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.0ms
# Speed: 2.1ms preprocess, 9.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.0ms
# Speed: 3.8ms preprocess, 9.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.9ms
# Speed: 2.1ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.7ms
# Speed: 2.6ms preprocess, 10.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.5ms
# Speed: 4.3ms preprocess, 9.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 12.0ms
# Speed: 2.7ms preprocess, 12.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.4ms
# Speed: 2.5ms preprocess, 9.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 9.0ms
# Speed: 3.1ms preprocess, 9.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 10.7ms
# Speed: 1.9ms preprocess, 10.7ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 17.4ms
# Speed: 2.7ms preprocess, 17.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 14.2ms
# Speed: 3.4ms preprocess, 14.2ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 13.8ms
# Speed: 5.3ms preprocess, 13.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 13.4ms
# Speed: 3.5ms preprocess, 13.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 15.0ms
# Speed: 3.7ms preprocess, 15.0ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 15.4ms
# Speed: 3.9ms preprocess, 15.4ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 15.4ms
# Speed: 3.6ms preprocess, 15.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire, 14.6ms
# Speed: 4.0ms preprocess, 14.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# 🚨 Fire detected at: Left, Top, Far
#
# 0: 384x640 1 fire,